# %%
from sympy import init_session
from sympy import div, QQ
from sympy.parsing.latex import parse_latex
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import Markdown as md
from IPython.display import display
import pandas as pd

import numpy as np




init_session()

a, b, c, d = symbols('a b c d', real = True)
from docparts import añadir_ejercicios, doc_ejer, escribir_preambulo, escribir_ejercicios, escribir_fin

df_ejercicios = pd.DataFrame()

fichero = 'limiteslh'
titulo = 'Límites L`Hopital'
curso = '2BC'


x,y = symbols('x, y', real=True)

import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
style.use('seaborn-whitegrid')


# %matplotlib inline
# Out:
# IPython console for SymPy 1.4 (Python 3.6.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
puntuacion = '1'                          
                      
datos = [['(x**4-20*x-21)/(x**2+11*x-42)',3],['(x**3-7*x+3)/(3-x-5*x**3)',oo],['sin(x)/x',0],['(E**x-1)/x',0],
         ['(1-cos(x))/x**2',0], ['(sin(x)-x+x**2/6)/x**3',0],['(atan(x)-x-x**3/3)/x**3',0],
         ['(x-sin(x))/x*sin(x)',0],['(1/x-1/sin(x))',0], ['1/x*log(sin(x)/x,10)',0],
         ['(1-E**(-x))**(x**2)',oo], ['cos(2*x)**(3/x**2)',0], ['tan(pi*x/4)**tan(pi*x/2)',1],
         ['x**(1/(1-x))',1], ['1/x*log(tan(x)/x,10)',0]

         ]
        
n_ejercicio = 'p33e52'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula los siguientes límites:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$'+latex(Limit(S(t[0],evaluate=False),x,t[1],dir='+-'))+r'$')
    enunciado.append(r'diff('+str(Limit(S(t[0],evaluate=False),x,t[1],dir='+-'))+r')')
    sol=r"$"+latex(limit(S(t[0],evaluate=False),'x',t[1]))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula los siguientes límites:
# **
# $\lim_{x \to 3}\left(\frac{x^{4} - 20 x - 21}{x^{2} + 11 x - 42}\right)$ $ \rightarrow $$\frac{88}{17}$
# $\lim_{x \to \infty}\left(\frac{x^{3} - 7 x + 3}{- 5 x^{3} - x + 3}\right)$ $ \rightarrow $$- \frac{1}{5}$
# $\lim_{x \to 0}\left(\frac{\sin{\left(x \right)}}{x}\right)$ $ \rightarrow $$1$
# $\lim_{x \to 0}\left(\frac{e^{x} - 1}{x}\right)$ $ \rightarrow $$1$
# $\lim_{x \to 0}\left(\frac{1 - \cos{\left(x \right)}}{x^{2}}\right)$ $ \rightarrow $$\frac{1}{2}$
# $\lim_{x \to 0}\left(\frac{\frac{x^{2}}{6} - x + \sin{\left(x \right)}}{x^{3}}\right)$ $ \rightarrow $$\infty$
# $\lim_{x \to 0}\left(\frac{- \frac{x^{3}}{3} - x + \operatorname{atan}{\left(x \right)}}{x^{3}}\right)$ $ \rightarrow $$- \frac{2}{3}$
# $\lim_{x \to 0}\left(\frac{\left(x - \sin{\left(x \right)}\right) \sin{\left(x \right)}}{x}\right)$ $ \rightarrow $$0$
# $\lim_{x \to 0}\left(- \frac{1}{\sin{\left(x \right)}} + \frac{1}{x}\right)$ $ \rightarrow $$0$
# ...

# %%
puntuacion = '1'                          
                      
datos = [['(log(E**x+x**3))/x',0], ['(1+1/x)**(1/2)-(1+4/x)**(1/2)',0], 
         ['(a**x-b**x)/x',0], ['(log(cos(3*x)))/x**2',0],
         ['(sin(x)-cos(x))/(1-cos(x))',0],['(log(1+x))/(root(x**3,4))',0],
         ['(2*(cos(x)+sin(x)))/x',0],['(log((1+x)/x))/(1/x)',oo],
         ['(x**3+1)/(x**2-3*x+4)',-1],['(x-sin(x))/(tan(x)-x)',0],
         ['(1-cos(x))/(sin(x)+cos(x))',0]

         ]
        
n_ejercicio = 'p33e53'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula los siguientes límites:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$'+latex(Limit(S(t[0],evaluate=False),x,t[1],dir='+-'))+r'$')
    enunciado.append(r'diff('+str(Limit(S(t[0],evaluate=False),x,t[1],dir='+-'))+r')')
    sol=r"$"+latex(limit(S(t[0],evaluate=False),'x',t[1]))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula los siguientes límites:
# **
# $\lim_{x \to 0}\left(\frac{\log{\left(e^{x} + x^{3} \right)}}{x}\right)$ $ \rightarrow $$1$
# $\lim_{x \to 0}\left(\left(1 + \frac{1}{x}\right)^{\frac{1}{2}} - \left(1 + \frac{4}{x}\right)^{\frac{1}{2}}\right)$ $ \rightarrow $$-\infty$
# $\lim_{x \to 0}\left(\frac{a^{x} - b^{x}}{x}\right)$ $ \rightarrow $$\log{\left(a \right)} - \log{\left(b \right)}$
# $\lim_{x \to 0}\left(\frac{\log{\left(\cos{\left(3 x \right)} \right)}}{x^{2}}\right)$ $ \rightarrow $$- \frac{9}{2}$
# $\lim_{x \to 0}\left(\frac{\sin{\left(x \right)} - \cos{\left(x \right)}}{1 - \cos{\left(x \right)}}\right)$ $ \rightarrow $$-\infty$
# $\lim_{x \to 0}\left(\frac{\log{\left(x + 1 \right)}}{\sqrt[4]{x^{3}}}\right)$ $ \rightarrow $$0$
# $\lim_{x \to 0}\left(\frac{2 \left(\sin{\left(x \right)} + \cos{\left(x \right)}\right)}{x}\right)$ $ \rightarrow $$\infty$
# $\lim_{x \to \infty}\left(\frac{\log{\left(\frac{x + 1}{x} \right)}}{\frac{1}{x}}\right)$ $ \rightarrow $$1$
# ...

# %%
puntuacion = '1'                          
                      
datos = [['cos(x)*log(tan(x))',pi/2],['(cos(x)+sin(x))**(1/x)',0],
         ['(tan(x))**cos(x)',pi/2],['(E**x+x**3)**(1/x)',0],
         ['(E**sin(x)-1)*tan(x+pi/2)',0],['(1+x)**x',oo],
         ['x*log((1+x)/x)',oo], ['(1-sin(2*x))**cot(3*x)',0],
         ['(1/x)**tan(x)',0],['sqrt(x**2+x+2)-x',oo],['tan(x)**(1/cos(2*x))',pi/2],
         ['cot(x)**sin(x)',0],['5*cot(x/2)*sqrt(1-cos(x))',0],
         ['((1+x)/(1+x+x**2))*(1+cot(x)**2)',0],
         ['((1/cos(2*x))-(tan(x)/(1-4*x/pi)))',pi/2],
         ['(1-cos(x))*cot(x)',0]

         ]
        
n_ejercicio = 'p33e54'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula los siguientes límites:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$'+latex(Limit(S(t[0],evaluate=False),x,t[1],dir='+-'))+r'$')
    enunciado.append(r'diff('+str(Limit(S(t[0],evaluate=False),x,t[1],dir='+-'))+r')')
    sol=r"$"+latex(limit(S(t[0],evaluate=False),'x',t[1]))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula los siguientes límites:
# **
# $\lim_{x \to \frac{\pi}{2}}\left(\log{\left(\tan{\left(x \right)} \right)} \cos{\left(x \right)}\right)$ $ \rightarrow $$0$
# $\lim_{x \to 0} \left(\sin{\left(x \right)} + \cos{\left(x \right)}\right)^{\frac{1}{x}}$ $ \rightarrow $$e$
# $\lim_{x \to \frac{\pi}{2}} \tan^{\cos{\left(x \right)}}{\left(x \right)}$ $ \rightarrow $$1$
# $\lim_{x \to 0} \left(e^{x} + x^{3}\right)^{\frac{1}{x}}$ $ \rightarrow $$e$
# $\lim_{x \to 0}\left(\left(e^{\sin{\left(x \right)}} - 1\right) \tan{\left(x + \frac{\pi}{2} \right)}\right)$ $ \rightarrow $$-1$
# $\lim_{x \to \infty} \left(x + 1\right)^{x}$ $ \rightarrow $$\infty$
# $\lim_{x \to \infty}\left(x \log{\left(\frac{x + 1}{x} \right)}\right)$ $ \rightarrow $$1$
# $\lim_{x \to 0} \left(1 - \sin{\left(2 x \right)}\right)^{\cot{\left(3 x \right)}}$ $ \rightarrow $$e^{- \frac{2}{3}}$
# $\lim_{x \to 0} \left(\frac{1}{x}\right)^{\tan{\left(x \right)}}$ $ \rightarrow $$1$
# ...

# %%
df_ejercicios
# Out:
#                                       enunciado_latex  \
# 0   $\lim_{x \to 3}\left(\frac{x^{4} - 20 x - 21}{...
# 1   $\lim_{x \to \infty}\left(\frac{x^{3} - 7 x + ...
# 2   $\lim_{x \to 0}\left(\frac{\sin{\left(x \right...
# 3    $\lim_{x \to 0}\left(\frac{e^{x} - 1}{x}\right)$
# 4   $\lim_{x \to 0}\left(\frac{1 - \cos{\left(x \r...
# 5   $\lim_{x \to 0}\left(\frac{\frac{x^{2}}{6} - x...
# 6   $\lim_{x \to 0}\left(\frac{- \frac{x^{3}}{3} -...
# 7   $\lim_{x \to 0}\left(\frac{\left(x - \sin{\lef...
# 8   $\lim_{x \to 0}\left(- \frac{1}{\sin{\left(x \...
# 9   $\lim_{x \to 0}\left(\frac{\frac{1}{\log{\left...
# 10  $\lim_{x \to \infty} \left(1 - e^{- x}\right)^...
# 11  $\lim_{x \to 0} \cos^{\frac{3}{x^{2}}}{\left(2...
# 12  $\lim_{x \to 1} \tan^{\tan{\left(\frac{\pi x}{...
# 13               $\lim_{x \to 1} x^{\frac{1}{1 - x}}$
# 14  $\lim_{x \to 0}\left(\frac{\frac{1}{\log{\left...
# 15  $\lim_{x \to 0}\left(\frac{\log{\left(e^{x} + ...
# ...

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p33e52
#                                       enunciado_latex  \
# 0   $\lim_{x \to 3}\left(\frac{x^{4} - 20 x - 21}{...
# 1   $\lim_{x \to \infty}\left(\frac{x^{3} - 7 x + ...
# 2   $\lim_{x \to 0}\left(\frac{\sin{\left(x \right...
# 3    $\lim_{x \to 0}\left(\frac{e^{x} - 1}{x}\right)$
# 4   $\lim_{x \to 0}\left(\frac{1 - \cos{\left(x \r...
# 5   $\lim_{x \to 0}\left(\frac{\frac{x^{2}}{6} - x...
# 6   $\lim_{x \to 0}\left(\frac{- \frac{x^{3}}{3} -...
# 7   $\lim_{x \to 0}\left(\frac{\left(x - \sin{\lef...
# 8   $\lim_{x \to 0}\left(- \frac{1}{\sin{\left(x \...
# 9   $\lim_{x \to 0}\left(\frac{\frac{1}{\log{\left...
# 10  $\lim_{x \to \infty} \left(1 - e^{- x}\right)^...
# 11  $\lim_{x \to 0} \cos^{\frac{3}{x^{2}}}{\left(2...
# 12  $\lim_{x \to 1} \tan^{\tan{\left(\frac{\pi x}{...
# 13               $\lim_{x \to 1} x^{\frac{1}{1 - x}}$
# 14  $\lim_{x \to 0}\left(\frac{\frac{1}{\log{\left...
#
# ...

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p33e52
#                                       enunciado_latex  \
# 0   $\lim_{x \to 3}\left(\frac{x^{4} - 20 x - 21}{...
# 1   $\lim_{x \to \infty}\left(\frac{x^{3} - 7 x + ...
# 2   $\lim_{x \to 0}\left(\frac{\sin{\left(x \right...
# 3    $\lim_{x \to 0}\left(\frac{e^{x} - 1}{x}\right)$
# 4   $\lim_{x \to 0}\left(\frac{1 - \cos{\left(x \r...
# 5   $\lim_{x \to 0}\left(\frac{\frac{x^{2}}{6} - x...
# 6   $\lim_{x \to 0}\left(\frac{- \frac{x^{3}}{3} -...
# 7   $\lim_{x \to 0}\left(\frac{\left(x - \sin{\lef...
# 8   $\lim_{x \to 0}\left(- \frac{1}{\sin{\left(x \...
# 9   $\lim_{x \to 0}\left(\frac{\frac{1}{\log{\left...
# 10  $\lim_{x \to \infty} \left(1 - e^{- x}\right)^...
# 11  $\lim_{x \to 0} \cos^{\frac{3}{x^{2}}}{\left(2...
# 12  $\lim_{x \to 1} \tan^{\tan{\left(\frac{\pi x}{...
# 13               $\lim_{x \to 1} x^{\frac{1}{1 - x}}$
# 14  $\lim_{x \to 0}\left(\frac{\frac{1}{\log{\left...
#
# ...
