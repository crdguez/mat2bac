# %%
from sympy import *
init_session()
from IPython.display import display_latex
# Out:
# IPython console for SymPy 1.8 (Python 3.6.13-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.8/

# %%
# %matplotlib inline

datos = [-x**2+6*x-5, x*(x-1)**2, 2*x**3-15*x**2+36*x-12, 2/(1+x**2),(8*x)/(x**2+2),
         x*log(x), x**2*E**x, x/log(x), x-sin(x), x+cos(x), 2*sin(x)- sin(2*x)
        ]

for f in datos :
    display('----------------------------------------------------------------------------------------------------')
    display([f,f.diff().simplify(),f.diff().diff().simplify()], [[i,f.diff().diff().subs(x,i)] for i in solve(f.diff())])
    display("función, derivada, derivada segunda: ")
    display([f,f.diff().simplify(),f.diff().diff().simplify()])
#     display_latex("funcion" + latex(f))
    plot(f)
# Out:
# '----------------------------------------------------------------------------------------------------'
# ⎡   2                       ⎤
# ⎣- x  + 6⋅x - 5, 6 - 2⋅x, -2⎦
# [[3, -2]]
# 'función, derivada, derivada segunda: '
# ⎡   2                       ⎤
# ⎣- x  + 6⋅x - 5, 6 - 2⋅x, -2⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡         2                            ⎤
# ⎣x⋅(x - 1) , (x - 1)⋅(3⋅x - 1), 6⋅x - 4⎦
# [[1/3, -2], [1, 2]]
# 'función, derivada, derivada segunda: '
# ⎡         2                            ⎤
# ⎣x⋅(x - 1) , (x - 1)⋅(3⋅x - 1), 6⋅x - 4⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡   3       2                 2                       ⎤
# ⎣2⋅x  - 15⋅x  + 36⋅x - 12, 6⋅x  - 30⋅x + 36, 12⋅x - 30⎦
# [[2, -6], [3, 6]]
# 'función, derivada, derivada segunda: '
# ⎡   3       2                 2                       ⎤
# ⎣2⋅x  - 15⋅x  + 36⋅x - 12, 6⋅x  - 30⋅x + 36, 12⋅x - 30⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡                     ⎛   2    ⎞⎤
# ⎢  2       -4⋅x     4⋅⎝3⋅x  - 1⎠⎥
# ⎢──────, ─────────, ────────────⎥
# ⎢ 2              2           3  ⎥
# ⎢x  + 1  ⎛ 2    ⎞    ⎛ 2    ⎞   ⎥
# ⎣        ⎝x  + 1⎠    ⎝x  + 1⎠   ⎦
# [[0, -4]]
# 'función, derivada, derivada segunda: '
# ⎡                     ⎛   2    ⎞⎤
# ⎢  2       -4⋅x     4⋅⎝3⋅x  - 1⎠⎥
# ⎢──────, ─────────, ────────────⎥
# ⎢ 2              2           3  ⎥
# ⎢x  + 1  ⎛ 2    ⎞    ⎛ 2    ⎞   ⎥
# ⎣        ⎝x  + 1⎠    ⎝x  + 1⎠   ⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡            ⎛     2⎞        ⎛ 2    ⎞⎤
# ⎢ 8⋅x      8⋅⎝2 - x ⎠   16⋅x⋅⎝x  - 6⎠⎥
# ⎢──────, ─────────────, ─────────────⎥
# ⎢ 2       4      2                3  ⎥
# ⎢x  + 2  x  + 4⋅x  + 4    ⎛ 2    ⎞   ⎥
# ⎣                         ⎝x  + 2⎠   ⎦
# [[-√2, √2], [√2, -√2]]
# 'función, derivada, derivada segunda: '
# ⎡            ⎛     2⎞        ⎛ 2    ⎞⎤
# ⎢ 8⋅x      8⋅⎝2 - x ⎠   16⋅x⋅⎝x  - 6⎠⎥
# ⎢──────, ─────────────, ─────────────⎥
# ⎢ 2       4      2                3  ⎥
# ⎢x  + 2  x  + 4⋅x  + 4    ⎛ 2    ⎞   ⎥
# ⎣                         ⎝x  + 2⎠   ⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡                      1⎤
# ⎢x⋅log(x), log(x) + 1, ─⎥
# ⎣                      x⎦
# ⎡⎡ -1   ⎤⎤
# ⎣⎣ℯ  , ℯ⎦⎦
# 'función, derivada, derivada segunda: '
# ⎡                      1⎤
# ⎢x⋅log(x), log(x) + 1, ─⎥
# ⎣                      x⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡ 2  x             x  ⎛ 2          ⎞  x⎤
# ⎣x ⋅ℯ , x⋅(x + 2)⋅ℯ , ⎝x  + 4⋅x + 2⎠⋅ℯ ⎦
# ⎡⎡        -2⎤        ⎤
# ⎣⎣-2, -2⋅ℯ  ⎦, [0, 2]⎦
# 'función, derivada, derivada segunda: '
# ⎡ 2  x             x  ⎛ 2          ⎞  x⎤
# ⎣x ⋅ℯ , x⋅(x + 2)⋅ℯ , ⎝x  + 4⋅x + 2⎠⋅ℯ ⎦
# '----------------------------------------------------------------------------------------------------'
# ⎡  x     log(x) - 1  2 - log(x)⎤
# ⎢──────, ──────────, ──────────⎥
# ⎢log(x)      2            3    ⎥
# ⎣         log (x)    x⋅log (x) ⎦
# ⎡⎡    -1⎤⎤
# ⎣⎣ℯ, ℯ  ⎦⎦
# 'función, derivada, derivada segunda: '
# ⎡  x     log(x) - 1  2 - log(x)⎤
# ⎢──────, ──────────, ──────────⎥
# ⎢log(x)      2            3    ⎥
# ⎣         log (x)    x⋅log (x) ⎦
# '----------------------------------------------------------------------------------------------------'
# [x - sin(x), 1 - cos(x), sin(x)]
# [[0, 0], [2⋅π, 0]]
# 'función, derivada, derivada segunda: '
# [x - sin(x), 1 - cos(x), sin(x)]
# '----------------------------------------------------------------------------------------------------'
# [x + cos(x), 1 - sin(x), -cos(x)]
# ⎡⎡π   ⎤⎤
# ⎢⎢─, 0⎥⎥
# ⎣⎣2   ⎦⎦
# 'función, derivada, derivada segunda: '
# [x + cos(x), 1 - sin(x), -cos(x)]
# '----------------------------------------------------------------------------------------------------'
# [2⋅sin(x) - sin(2⋅x), 2⋅cos(x) - 2⋅cos(2⋅x), 2⋅(4⋅cos(x) - 1)⋅sin(x)]
# ⎡        ⎡-4⋅π        ⎤  ⎡-2⋅π       ⎤  ⎡2⋅π       ⎤  ⎡4⋅π      ⎤          ⎤
# ⎢[0, 0], ⎢─────, -3⋅√3⎥, ⎢─────, 3⋅√3⎥, ⎢───, -3⋅√3⎥, ⎢───, 3⋅√3⎥, [2⋅π, 0]⎥
# ⎣        ⎣  3         ⎦  ⎣  3        ⎦  ⎣ 3        ⎦  ⎣ 3       ⎦          ⎦
# 'función, derivada, derivada segunda: '
# [2⋅sin(x) - sin(2⋅x), 2⋅cos(x) - 2⋅cos(2⋅x), 2⋅(4⋅cos(x) - 1)⋅sin(x)]
